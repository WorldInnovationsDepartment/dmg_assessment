# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/wbw520/RTFP.git
# Out:
# Cloning into 'RTFP'...
# remote: Enumerating objects: 286, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (194/194), done.
# remote: Total 286 (delta 164), reused 199 (delta 89), pack-reused 0
# Receiving objects: 100% (286/286), 1.88 MiB | 11.24 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# %cd /content
# !python /content/RTFP/data/facade_data_generation.py --root "/content/RTFP"
# Out:
# /content
# 37695625324_7791a4ee01_b
# 1650180454137
# 1650180454289
# IMG_20220313_115310
# WeChat Image_20220320173633
# IMG_20220313_114211
# second_113
# 31088473521_c3d35f4cd2_b
# 1650180454270
# IMG_1296
# photo-1547499681-28dece7dba00
# WeChat Image_20220320173811
# IMG_20220313_125051
# 14313638582_f89d21e8d0_b
# IMG_1279
# second_151
# IMG_1281
# 41030025360_94d22bcb53_k
# WeChat Image_20220320173628
# IMG_E1284
# 1650180455023
# second_47
# second_97
# IMG_1290
# 22703140560_7dceeec9a4_b
# photo-1528061572073-c50e6fc37e0b
# second_43
# mmexport1651673623397
# second_175
# second_74
# second_136
# second_93
# 1650180454776
# 1650180454220
# IMG_20220313_112426
# photo-1483097365279-e8acd3bf9f18
# IMG_1277
# second_155
# IMG_E1321
# 5351509500_986aaa1ce8_b
# 1650180453988
# IMG_E1270
# second_144
# 1650180454449
# second_176
# photo-1590812313349-2737113c3c05
# 32052284_477d66a5ae_o
# IMG_20220313_124717
# photo-1618052356974-0aabc72eb478
# 1650180454742
# ...

# %%
# !pip install timm einops

# %%
# !python /content/RTFP/train.py --model_name Segmenter --batch_size 4 --root "/content/drive/MyDrive/"
# Out:
# Not using distributed mode
# [08:23:20.653948] load pre-model trained by ImageNet
# [08:23:29.982297] load pre-trained weight from:  ViT-B_16.npz
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [08:23:30.576513] AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.95)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0.01
# )
# [08:23:30.576658] Start training for 60 epochs
# [08:23:30.576723] Epoch 1/60
# ...

# %%
# !python /content/RTFP/inference.py --model_name Segmenter --eval_img "/content/drive/MyDrive/Facade/translated_data/images/32495490577_7b4f20f1bc_b.png"
# Out:
# Not using distributed mode
# [09:44:11.498745] load pre-model trained by ImageNet
# [09:44:12.599811] load pre-trained weight from:  ViT-B_16.npz
# [09:44:17.481179] Figure(2048x1024)
# [09:44:18.231674] Figure(2048x1024)

# %%
# !zip -r /content/RTFP.zip /content/RTFP
# Out:
#   adding: content/RTFP/ (stored 0%)
#   adding: content/RTFP/.git/ (stored 0%)
#   adding: content/RTFP/.git/packed-refs (deflated 11%)
#   adding: content/RTFP/.git/config (deflated 31%)
#   adding: content/RTFP/.git/branches/ (stored 0%)
#   adding: content/RTFP/.git/objects/ (stored 0%)
#   adding: content/RTFP/.git/objects/pack/ (stored 0%)
#   adding: content/RTFP/.git/objects/pack/pack-c1151bc6bab29f0e010c9790bb6b60f9faf3d2ae.pack (deflated 0%)
#   adding: content/RTFP/.git/objects/pack/pack-c1151bc6bab29f0e010c9790bb6b60f9faf3d2ae.idx (deflated 8%)
#   adding: content/RTFP/.git/objects/info/ (stored 0%)
#   adding: content/RTFP/.git/hooks/ (stored 0%)
#   adding: content/RTFP/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/RTFP/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/RTFP/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/RTFP/.git/hooks/pre-push.sample (deflated 49%)
# ...
